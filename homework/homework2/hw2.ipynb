# %%
import sys, os
print("Python version:", sys.version)
print("Interpreter path:", sys.executable)
try:
    import numpy as np
    from dotenv import load_dotenv
    print("Imports OK")
except Exception as e:
    print("Import error:", e)
    raise
# Out:
# Python version: 3.10.18 | packaged by Anaconda, Inc. | (main, Jun  5 2025, 13:08:55) [MSC v.1929 64 bit (AMD64)]
# Interpreter path: C:\Users\kidney\miniconda3\envs\bootcamp_env\python.exe
# Imports OK
# .env loaded (if present)

# %%
from pathlib import Path
load_dotenv()  # looks for a .env file in the current and parent directories
print(".env loaded (if present)")
# Out:
# .env loaded (if present)

# %%
# src/config.py (inline demo)
from typing import Optional

def get_key(name: str, default: Optional[str] = None) -> Optional[str]:
    return os.getenv(name, default)

PROJECT_ROOT = Path.cwd()
DATA_DIR = PROJECT_ROOT / "data"
print("PROJECT_ROOT:", PROJECT_ROOT)
print("DATA_DIR:", DATA_DIR)
# Out:
# PROJECT_ROOT: C:\Users\kidney\bootcamp_xiaoyang_zhang\homework\homework2
# DATA_DIR: C:\Users\kidney\bootcamp_xiaoyang_zhang\homework\homework2\data

# %%
load_env()
api_key_present = get_key("API_KEY") is not None
print("API_KEY present:", api_key_present)

arr = np.array([1, 2, 3])
print("NumPy test:", arr * 2)
# Out:
# API_KEY present: True
# NumPy test: [2 4 6]
